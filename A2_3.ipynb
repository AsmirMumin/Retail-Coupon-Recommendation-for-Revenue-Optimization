# %% [markdown]
# # Machine Learning in Marketing 2020/21
# ## Assignment 2.3

# %%
# set working directory
# %cd C:/Users/Christopher/Documents/MLiM/Ass2/
# Out:
# C:\Users\Christopher\Documents\MLiM\Ass2

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install pyarrow

# %%
#load the data
aisles = pd.read_parquet("aisles.parquet")
dept = pd.read_parquet("departments.parquet")
pred_idx = pd.read_parquet("prediction_index.parquet")
orders = pd.read_parquet("orders.parquet")
prod = pd.read_parquet("products.parquet")
baskets = pd.read_parquet("baskets.parquet")

# %%
print("Shape of aisles: ", aisles.shape)
print("Shape of departments: ", dept.shape)
print("Shape of pred_idx: ", pred_idx.shape)
print("Shape of orders: ", orders.shape)
print("Shape of products: ", prod.shape)
print("Shape of baskets: ", baskets.shape)
# Out:
# Shape of aisles:  (134, 2)
# Shape of departments:  (21, 2)
# Shape of pred_idx:  (206209, 2)
# Shape of orders:  (3214874, 6)
# Shape of products:  (49688, 4)
# Shape of baskets:  (32434489, 4)

# %%
print("Variable names of aisles: ", list(aisles.columns))
print("Variable names of departments: ", list(dept.columns))
print("Variable names of pred_idx: ", list(pred_idx.columns))
print("Variable names of orders: ", list(orders.columns))
print("Variable names of products: ", list(prod.columns))
print("Variable names of baskets: ", list(baskets.columns))
# Out:
# Variable names of aisles:  ['aisle_id', 'aisle']
# Variable names of departments:  ['department_id', 'department']
# Variable names of pred_idx:  ['user_id', 'order_number']
# Variable names of orders:  ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
# Variable names of products:  ['product_id', 'product_name', 'aisle_id', 'department_id']
# Variable names of baskets:  ['order_id', 'product_id', 'add_to_cart_order', 'reordered']

# %%
# inner join of basket and products
baskets_prod = pd.merge(baskets, prod, on="product_id", how="inner")
baskets_prod.shape
# Out:
# (32434489, 7)

# %%
# inner join of baskets_prod and orders
baskets_prod_orders = pd.merge(baskets_prod, orders, on="order_id", how="inner")
baskets_prod_orders.shape
# Out:
# (32434489, 12)

# %%
# left join of baskets_prod_orders and department
baskets_prod_orders_dept = pd.merge(baskets_prod_orders, dept, on="department_id", how="left")
baskets_prod_orders_dept.shape
# Out:
# (32434489, 13)

# %%
# left join of baskets_prod_orders_dept and aisles
df = pd.merge(baskets_prod_orders_dept, aisles, on="aisle_id", how="left")
df.shape
# Out:
# (32434489, 14)

# %% [markdown]
# ## EDA

# %%
df.head(20)
# Out:
#     order_id  product_id  add_to_cart_order  reordered  \
# 0          2       33120                  1          1
# 1          2       28985                  2          1
# 2          2       45918                  4          1
# 3          2        1819                  8          1
# 4          2       30035                  5          0
# 5          2       17794                  6          1
# 6          2       40141                  7          1
# 7          2       43668                  9          0
# 8          2        9327                  3          0
# 9         26       33120                  5          0
# 10        26       21903                  6          0
# 11        26       24852                  2          1
# 12        26       47766                  8          1
# 13        26       46206                  3          0
# 14        26       40545                  7          0
# 15        26       25890                  4          0
# 16        26       35951                  1          0
# 17       120       33120                 13          0
# 18       120       41273                  4          0
# 19       120       40545                  1          0
#
#                                 product_name  aisle_id  department_id  \
# 0                         Organic Egg Whites        86             16
# 1                      Michigan Organic Kale        83              4
# 2                             Coconut Butter        19             13
# 3   All Natural No Stir Creamy Almond Butter        88             13
# 4                          Natural Sweetener        17             13
# 5                                    Carrots        83              4
# 6           Original Unflavored Gelatine Mix       105             13
# 7                    Classic Blend Cole Slaw       123              4
# 8                              Garlic Powder       104             13
# 9                         Organic Egg Whites        86             16
# 10                      Organic Baby Spinach       123              4
# 11                                    Banana        24              4
# 12                           Organic Avocado        24              4
# 13                            Red Grapefruit        24              4
# 14                              Berry Medley       116              1
# 15         Boneless Skinless Chicken Breasts        49             12
# 16           Organic Unsweetened Almond Milk        91             16
# 17                        Organic Egg Whites        86             16
# 18                          Broccoli Florets       123              4
# 19                              Berry Medley       116              1
#
#     user_id  order_number  order_dow  order_hour_of_day  \
# 0    202279             3          5                  9
# 1    202279             3          5                  9
# 2    202279             3          5                  9
# 3    202279             3          5                  9
# 4    202279             3          5                  9
# 5    202279             3          5                  9
# 6    202279             3          5                  9
# 7    202279             3          5                  9
# 8    202279             3          5                  9
# 9    153404             2          0                 16
# 10   153404             2          0                 16
# 11   153404             2          0                 16
# 12   153404             2          0                 16
# 13   153404             2          0                 16
# 14   153404             2          0                 16
# 15   153404             2          0                 16
# 16   153404             2          0                 16
# 17    23750            11          6                  8
# 18    23750            11          6                  8
# 19    23750            11          6                  8
#
#     days_since_prior_order    department                       aisle
# 0                      8.0    dairy eggs                        eggs
# 1                      8.0       produce            fresh vegetables
# 2                      8.0        pantry               oils vinegars
# 3                      8.0        pantry                     spreads
# 4                      8.0        pantry          baking ingredients
# 5                      8.0       produce            fresh vegetables
# 6                      8.0        pantry  doughs gelatins bake mixes
# 7                      8.0       produce  packaged vegetables fruits
# 8                      8.0        pantry           spices seasonings
# 9                      7.0    dairy eggs                        eggs
# 10                     7.0       produce  packaged vegetables fruits
# 11                     7.0       produce                fresh fruits
# 12                     7.0       produce                fresh fruits
# 13                     7.0       produce                fresh fruits
# 14                     7.0        frozen              frozen produce
# 15                     7.0  meat seafood            packaged poultry
# 16                     7.0    dairy eggs             soy lactosefree
# 17                    10.0    dairy eggs                        eggs
# 18                    10.0       produce  packaged vegetables fruits
# 19                    10.0        frozen              frozen produce

# %%
# some visualisations
fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(12,5))
axs[0].hist(df["order_hour_of_day"])
axs[0].set_title('order_hour_of_day')
axs[0].set_xlabel('hour')

axs[1].hist(df["days_since_prior_order"])
axs[1].set_xlabel('days')
axs[1].set_title('days_since_prior_order')

plt.show()

# %% [markdown]
# ## Data Transformation

# %%
# group dataframe by order_id
df_1 = df.groupby(by="order_id").mean()
df_1
# Out:
#             product_id  add_to_cart_order  reordered   aisle_id  \
# order_id
# 2         27867.444444                5.0   0.666667  78.666667
# 3         26582.500000                4.5   1.000000  97.250000
# 4         29740.615385                7.0   0.923077  59.076923
# 5         29484.692308               13.5   0.807692  57.846154
# 6         32744.000000                2.0   0.000000  69.000000
# ...                ...                ...        ...        ...
# 3421079   30136.000000                1.0   0.000000  25.000000
# 3421080   23560.000000                5.0   0.444444  56.888889
# 3421081   22054.714286                4.0   0.000000  80.428571
# 3421082   26118.571429                4.0   0.571429  61.714286
# 3421083   21321.400000                5.5   0.400000  71.600000
#
#           department_id   user_id  order_number  order_dow  order_hour_of_day  \
# order_id
# 2             10.333333  202279.0           3.0        5.0                9.0
# 3              9.375000  205970.0          16.0        5.0               17.0
# 4             12.846154  178520.0          36.0        1.0                9.0
# 5             11.653846  156122.0          42.0        6.0               16.0
# 6             13.666667   22352.0           4.0        1.0               12.0
# ...                 ...       ...           ...        ...                ...
# 3421079       11.000000  108687.0           6.0        1.0               13.0
# 3421080       10.666667   52726.0           2.0        1.0               11.0
# 3421081       13.285714  117076.0           1.0        3.0               11.0
# 3421082       12.142857  175185.0          23.0        2.0               18.0
# 3421083       15.100000   25247.0          24.0        2.0                6.0
#
#           days_since_prior_order
# order_id
# 2                            8.0
# 3                           12.0
# 4                            7.0
# 5                            9.0
# 6                           30.0
# ...                          ...
# 3421079                      0.0
# 3421080                      2.0
# 3421081                      NaN
# 3421082                      4.0
# 3421083                     21.0
#
# [3214874 rows x 10 columns]

# %%
# calculate number of items in one basket
df_1["item_count"] =df_1["add_to_cart_order"]*2-1
df_1
# Out:
#             product_id  add_to_cart_order  reordered   aisle_id  \
# order_id
# 2         27867.444444                5.0   0.666667  78.666667
# 3         26582.500000                4.5   1.000000  97.250000
# 4         29740.615385                7.0   0.923077  59.076923
# 5         29484.692308               13.5   0.807692  57.846154
# 6         32744.000000                2.0   0.000000  69.000000
# ...                ...                ...        ...        ...
# 3421079   30136.000000                1.0   0.000000  25.000000
# 3421080   23560.000000                5.0   0.444444  56.888889
# 3421081   22054.714286                4.0   0.000000  80.428571
# 3421082   26118.571429                4.0   0.571429  61.714286
# 3421083   21321.400000                5.5   0.400000  71.600000
#
#           department_id   user_id  order_number  order_dow  order_hour_of_day  \
# order_id
# 2             10.333333  202279.0           3.0        5.0                9.0
# 3              9.375000  205970.0          16.0        5.0               17.0
# 4             12.846154  178520.0          36.0        1.0                9.0
# 5             11.653846  156122.0          42.0        6.0               16.0
# 6             13.666667   22352.0           4.0        1.0               12.0
# ...                 ...       ...           ...        ...                ...
# 3421079       11.000000  108687.0           6.0        1.0               13.0
# 3421080       10.666667   52726.0           2.0        1.0               11.0
# 3421081       13.285714  117076.0           1.0        3.0               11.0
# 3421082       12.142857  175185.0          23.0        2.0               18.0
# 3421083       15.100000   25247.0          24.0        2.0                6.0
#
#           days_since_prior_order  item_count
# order_id
# 2                            8.0         9.0
# 3                           12.0         8.0
# 4                            7.0        13.0
# 5                            9.0        26.0
# 6                           30.0         3.0
# ...                          ...         ...
# 3421079                      0.0         1.0
# 3421080                      2.0         9.0
# 3421081                      NaN         7.0
# 3421082                      4.0         7.0
# 3421083                     21.0        10.0
#
# [3214874 rows x 11 columns]

# %%
# not needed - cannot be interpreted
df_1 = df_1.drop(columns=["aisle_id","department_id"])

# %%
# check dataframe for one exemplary customer
df_1[df_1["user_id"]==202279.0]
# Out:
#             product_id  add_to_cart_order  reordered   user_id  order_number  \
# order_id
# 2         27867.444444                5.0   0.666667  202279.0           3.0
# 104690    24877.000000                6.5   0.416667  202279.0           8.0
# 132412    28842.090909                6.0   0.818182  202279.0           6.0
# 1500071   20449.083333                6.5   0.250000  202279.0           2.0
# 2382766   27797.000000                9.0   0.529412  202279.0           7.0
# 2808715   23844.000000                6.0   0.727273  202279.0           5.0
# 2894949   18479.900000                5.5   0.000000  202279.0           1.0
# 3058248   25695.250000                4.5   0.375000  202279.0           4.0
#
#           order_dow  order_hour_of_day  days_since_prior_order  item_count
# order_id
# 2               5.0                9.0                     8.0         9.0
# 104690          6.0               10.0                    30.0        12.0
# 132412          5.0                9.0                    30.0        11.0
# 1500071         4.0               13.0                    20.0        12.0
# 2382766         1.0               14.0                    24.0        17.0
# 2808715         5.0               13.0                     9.0        11.0
# 2894949         5.0                9.0                     NaN        10.0
# 3058248         3.0               14.0                    30.0         8.0

# %%
# create dataframe with user_id as key, aggregating all orders of a user by calculating the mean
df_2 = df_1.groupby(by="user_id").mean()
df_2
# Out:
#             product_id  add_to_cart_order  reordered  order_number  order_dow  \
# user_id
# 1.0       17189.803611           3.450000   0.705833           5.5   2.500000
# 2.0       25507.097335           7.464286   0.447961           7.5   2.142857
# 3.0       27813.333333           4.166667   0.658817           6.5   1.083333
# 4.0       23471.276190           2.300000   0.028571           3.0   4.800000
# 5.0       22770.456692           5.125000   0.377778           2.5   1.750000
# ...                ...                ...        ...           ...        ...
# 206205.0  28366.204482           5.833333   0.369048           2.0   3.666667
# 206206.0  29294.680325           2.626866   0.570676          34.0   2.477612
# 206207.0  26865.592900           7.468750   0.637144           8.5   2.562500
# 206208.0  26133.179472           7.408163   0.700368          25.0   2.653061
# 206209.0  20739.342119           5.461538   0.536752           7.0   2.769231
#
#           order_hour_of_day  days_since_prior_order  item_count
# user_id
# 1.0               10.300000               19.555556    5.900000
# 2.0               10.571429               15.230769   13.928571
# 3.0               16.416667               12.090909    7.333333
# 4.0               12.600000               13.750000    3.600000
# 5.0               16.000000               13.333333    9.250000
# ...                     ...                     ...         ...
# 206205.0          14.333333               20.000000   10.666667
# 206206.0          16.731343                3.772727    4.253731
# 206207.0          12.500000               14.333333   13.937500
# 206208.0          14.265306                7.437500   13.816327
# 206209.0          13.615385               17.500000    9.923077
#
# [206209 rows x 8 columns]

# %%
# calculate number of orders
df_2["no_orders"] =df_2["order_number"]*2-1
df_2 = df_2.drop(columns=["order_number"])
df_2
# Out:
#             product_id  add_to_cart_order  reordered  order_dow  \
# user_id
# 1.0       17189.803611           3.450000   0.705833   2.500000
# 2.0       25507.097335           7.464286   0.447961   2.142857
# 3.0       27813.333333           4.166667   0.658817   1.083333
# 4.0       23471.276190           2.300000   0.028571   4.800000
# 5.0       22770.456692           5.125000   0.377778   1.750000
# ...                ...                ...        ...        ...
# 206205.0  28366.204482           5.833333   0.369048   3.666667
# 206206.0  29294.680325           2.626866   0.570676   2.477612
# 206207.0  26865.592900           7.468750   0.637144   2.562500
# 206208.0  26133.179472           7.408163   0.700368   2.653061
# 206209.0  20739.342119           5.461538   0.536752   2.769231
#
#           order_hour_of_day  days_since_prior_order  item_count  no_orders
# user_id
# 1.0               10.300000               19.555556    5.900000       10.0
# 2.0               10.571429               15.230769   13.928571       14.0
# 3.0               16.416667               12.090909    7.333333       12.0
# 4.0               12.600000               13.750000    3.600000        5.0
# 5.0               16.000000               13.333333    9.250000        4.0
# ...                     ...                     ...         ...        ...
# 206205.0          14.333333               20.000000   10.666667        3.0
# 206206.0          16.731343                3.772727    4.253731       67.0
# 206207.0          12.500000               14.333333   13.937500       16.0
# 206208.0          14.265306                7.437500   13.816327       49.0
# 206209.0          13.615385               17.500000    9.923077       13.0
#
# [206209 rows x 8 columns]

# %%
# not needed
df_2 = df_2.drop(columns=["add_to_cart_order"])

# %%
df_2 = df_2.rename(columns={"days_since_prior_order": "order_frequency_in_days"})
df_2 = df_2.rename(columns={"reordered": "reordered_ratio"})
df_2
# Out:
#             product_id  reordered_ratio  order_dow  order_hour_of_day  \
# user_id
# 1.0       17189.803611         0.705833   2.500000          10.300000
# 2.0       25507.097335         0.447961   2.142857          10.571429
# 3.0       27813.333333         0.658817   1.083333          16.416667
# 4.0       23471.276190         0.028571   4.800000          12.600000
# 5.0       22770.456692         0.377778   1.750000          16.000000
# ...                ...              ...        ...                ...
# 206205.0  28366.204482         0.369048   3.666667          14.333333
# 206206.0  29294.680325         0.570676   2.477612          16.731343
# 206207.0  26865.592900         0.637144   2.562500          12.500000
# 206208.0  26133.179472         0.700368   2.653061          14.265306
# 206209.0  20739.342119         0.536752   2.769231          13.615385
#
#           order_frequency_in_days  item_count  no_orders
# user_id
# 1.0                     19.555556    5.900000       10.0
# 2.0                     15.230769   13.928571       14.0
# 3.0                     12.090909    7.333333       12.0
# 4.0                     13.750000    3.600000        5.0
# 5.0                     13.333333    9.250000        4.0
# ...                           ...         ...        ...
# 206205.0                20.000000   10.666667        3.0
# 206206.0                 3.772727    4.253731       67.0
# 206207.0                14.333333   13.937500       16.0
# 206208.0                 7.437500   13.816327       49.0
# 206209.0                17.500000    9.923077       13.0
#
# [206209 rows x 7 columns]

# %%
# drop product_id
df_2 = df_2.drop(columns=["product_id"])
df_2
# Out:
#           reordered_ratio  order_dow  order_hour_of_day  \
# user_id
# 1.0              0.705833   2.500000          10.300000
# 2.0              0.447961   2.142857          10.571429
# 3.0              0.658817   1.083333          16.416667
# 4.0              0.028571   4.800000          12.600000
# 5.0              0.377778   1.750000          16.000000
# ...                   ...        ...                ...
# 206205.0         0.369048   3.666667          14.333333
# 206206.0         0.570676   2.477612          16.731343
# 206207.0         0.637144   2.562500          12.500000
# 206208.0         0.700368   2.653061          14.265306
# 206209.0         0.536752   2.769231          13.615385
#
#           order_frequency_in_days  item_count  no_orders
# user_id
# 1.0                     19.555556    5.900000       10.0
# 2.0                     15.230769   13.928571       14.0
# 3.0                     12.090909    7.333333       12.0
# 4.0                     13.750000    3.600000        5.0
# 5.0                     13.333333    9.250000        4.0
# ...                           ...         ...        ...
# 206205.0                20.000000   10.666667        3.0
# 206206.0                 3.772727    4.253731       67.0
# 206207.0                14.333333   13.937500       16.0
# 206208.0                 7.437500   13.816327       49.0
# 206209.0                17.500000    9.923077       13.0
#
# [206209 rows x 6 columns]

# %%
# reset proper indexing of dataframe and add user_id as a column
df_2["user_id"]=df_2.index
df_2["user_id"]=df_2["user_id"].astype(int)
df_2 = df_2.reset_index(drop=True)
df_2
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  \
# 0              0.705833   2.500000          10.300000
# 1              0.447961   2.142857          10.571429
# 2              0.658817   1.083333          16.416667
# 3              0.028571   4.800000          12.600000
# 4              0.377778   1.750000          16.000000
# ...                 ...        ...                ...
# 206204         0.369048   3.666667          14.333333
# 206205         0.570676   2.477612          16.731343
# 206206         0.637144   2.562500          12.500000
# 206207         0.700368   2.653061          14.265306
# 206208         0.536752   2.769231          13.615385
#
#         order_frequency_in_days  item_count  no_orders  user_id
# 0                     19.555556    5.900000       10.0        1
# 1                     15.230769   13.928571       14.0        2
# 2                     12.090909    7.333333       12.0        3
# 3                     13.750000    3.600000        5.0        4
# 4                     13.333333    9.250000        4.0        5
# ...                         ...         ...        ...      ...
# 206204                20.000000   10.666667        3.0   206205
# 206205                 3.772727    4.253731       67.0   206206
# 206206                14.333333   13.937500       16.0   206207
# 206207                 7.437500   13.816327       49.0   206208
# 206208                17.500000    9.923077       13.0   206209
#
# [206209 rows x 7 columns]

# %%
df.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2       45918                  4          1
# 3         2        1819                  8          1
# 4         2       30035                  5          0
# 5         2       17794                  6          1
# 6         2       40141                  7          1
# 7         2       43668                  9          0
# 8         2        9327                  3          0
# 9        26       33120                  5          0
#
#                                product_name  aisle_id  department_id  user_id  \
# 0                        Organic Egg Whites        86             16   202279
# 1                     Michigan Organic Kale        83              4   202279
# 2                            Coconut Butter        19             13   202279
# 3  All Natural No Stir Creamy Almond Butter        88             13   202279
# 4                         Natural Sweetener        17             13   202279
# 5                                   Carrots        83              4   202279
# 6          Original Unflavored Gelatine Mix       105             13   202279
# 7                   Classic Blend Cole Slaw       123              4   202279
# 8                             Garlic Powder       104             13   202279
# 9                        Organic Egg Whites        86             16   153404
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
# 5             3          5                  9                     8.0
# 6             3          5                  9                     8.0
# 7             3          5                  9                     8.0
# 8             3          5                  9                     8.0
# 9             2          0                 16                     7.0
#
#    department                       aisle
# 0  dairy eggs                        eggs
# 1     produce            fresh vegetables
# 2      pantry               oils vinegars
# 3      pantry                     spreads
# 4      pantry          baking ingredients
# 5     produce            fresh vegetables
# 6      pantry  doughs gelatins bake mixes
# 7     produce  packaged vegetables fruits
# 8      pantry           spices seasonings
# 9  dairy eggs                        eggs

# %%
df_1.head()
# Out:
#             product_id  add_to_cart_order  reordered   user_id  order_number  \
# order_id
# 2         27867.444444                5.0   0.666667  202279.0           3.0
# 3         26582.500000                4.5   1.000000  205970.0          16.0
# 4         29740.615385                7.0   0.923077  178520.0          36.0
# 5         29484.692308               13.5   0.807692  156122.0          42.0
# 6         32744.000000                2.0   0.000000   22352.0           4.0
#
#           order_dow  order_hour_of_day  days_since_prior_order  item_count
# order_id
# 2               5.0                9.0                     8.0         9.0
# 3               5.0               17.0                    12.0         8.0
# 4               1.0                9.0                     7.0        13.0
# 5               6.0               16.0                     9.0        26.0
# 6               1.0               12.0                    30.0         3.0

# %%
df_2.head()
# Out:
#    reordered_ratio  order_dow  order_hour_of_day  order_frequency_in_days  \
# 0         0.705833   2.500000          10.300000                19.555556
# 1         0.447961   2.142857          10.571429                15.230769
# 2         0.658817   1.083333          16.416667                12.090909
# 3         0.028571   4.800000          12.600000                13.750000
# 4         0.377778   1.750000          16.000000                13.333333
#
#    item_count  no_orders  user_id
# 0    5.900000       10.0        1
# 1   13.928571       14.0        2
# 2    7.333333       12.0        3
# 3    3.600000        5.0        4
# 4    9.250000        4.0        5

# %%
# list of orders - they are alredy sorted correctly
loo = df[["order_id","user_id","order_number"]].sort_values(by=["order_number"]).groupby(by="user_id").agg({'order_id':lambda x: list(x)}).reset_index(drop=False)
loo = loo.rename(columns={"order_id": "list_of_orders"})
# remove dublicates
loo["list_of_orders"] = loo["list_of_orders"].apply(lambda x: list(dict.fromkeys(x)))
loo.head()
# Out:
#    user_id                                     list_of_orders
# 0        1  [2539329, 2398795, 473747, 2254736, 431534, 33...
# 1        2  [2168274, 1501582, 1901567, 738281, 1673511, 1...
# 2        3  [1374495, 444309, 3002854, 2037211, 2710558, 1...
# 3        4         [3343014, 2030307, 691089, 94891, 2557754]
# 4        5                [2717275, 1909121, 2267326, 157374]

# %%
# check again for exemplary customer 5
df[df["user_id"]==5][["order_id","user_id","order_number"]].sort_values(by=["order_number"]).drop_duplicates()
# Out:
#           order_id  user_id  order_number
# 20221474   2717275        5             1
# 28731600   1909121        5             2
# 28321840   2267326        5             3
# 25337602    157374        5             4

# %%
print(f"Every customer has at least {min(loo.list_of_orders.apply(len))} orders.")
# Out:
# Every customer has at least 3 orders.

# %%
# get the last 4 order_id's
loo["order_lag_0"] = loo["list_of_orders"].apply(lambda x: x[-1])
loo["order_lag_1"] = loo["list_of_orders"].apply(lambda x: x[-2])
loo["order_lag_2"] = loo["list_of_orders"].apply(lambda x: x[-3])
loo["order_lag_3"] = loo["list_of_orders"].apply(lambda x: x[-4] if len(x)>3 else -1)
loo
# Out:
#         user_id                                     list_of_orders  \
# 0             1  [2539329, 2398795, 473747, 2254736, 431534, 33...
# 1             2  [2168274, 1501582, 1901567, 738281, 1673511, 1...
# 2             3  [1374495, 444309, 3002854, 2037211, 2710558, 1...
# 3             4         [3343014, 2030307, 691089, 94891, 2557754]
# 4             5                [2717275, 1909121, 2267326, 157374]
# ...         ...                                                ...
# 206204   206205                          [969311, 2658896, 414137]
# 206205   206206  [3189322, 3351137, 540764, 2975608, 2028659, 5...
# 206206   206207  [2166133, 1074448, 1666077, 2364140, 2277235, ...
# 206207   206208  [2227043, 1959749, 3392839, 731227, 2936891, 2...
# 206208   206209  [3154581, 1889163, 1542354, 688306, 2307371, 3...
#
#         order_lag_0  order_lag_1  order_lag_2  order_lag_3
# 0           2550362      2295261      3108588       550135
# 1            839880      3268552      3186735      1402090
# 2           1402502       521107       676467      3160850
# 3           2557754        94891       691089      2030307
# 4            157374      2267326      1909121      2717275
# ...             ...          ...          ...          ...
# 206204       414137      2658896       969311           -1
# 206205      1904200      2986341      2750895      2643521
# 206206      1005822      2991173      2832273      1452193
# 206207      1882108      1285346      2239861      3059777
# 206208      2977660       626363      1854736      2266710
#
# [206209 rows x 6 columns]

# %%
# merge: get the days_since_prior_order for each order_id, with user_id for later matching
lag_days_0 = pd.merge(loo["order_lag_0"], df[["order_id", "days_since_prior_order","user_id"]], how="left", left_on = ["order_lag_0"], right_on=["order_id"]).groupby(by="order_lag_0").max()
lag_days_0 = lag_days_0.rename(columns={"days_since_prior_order": "days_lag_0"}).drop(columns=["order_id"])

lag_days_1 = pd.merge(loo["order_lag_1"], df[["order_id", "days_since_prior_order","user_id"]], how="left", left_on = ["order_lag_1"], right_on=["order_id"]).groupby(by="order_lag_1").max()
lag_days_1 = lag_days_1.rename(columns={"days_since_prior_order": "days_lag_1"}).drop(columns=["order_id"])
lag_days_1

lag_days_2 = pd.merge(loo["order_lag_2"], df[["order_id", "days_since_prior_order","user_id"]], how="left", left_on = ["order_lag_2"], right_on=["order_id"]).groupby(by="order_lag_2").max()
lag_days_2 = lag_days_2.rename(columns={"days_since_prior_order": "days_lag_2"}).drop(columns=["order_id"])
lag_days_2

lag_days_3 = pd.merge(loo["order_lag_3"], df[["order_id", "days_since_prior_order","user_id"]], how="left", left_on = ["order_lag_3"], right_on=["order_id"]).groupby(by="order_lag_3").max()
lag_days_3 = lag_days_3.rename(columns={"days_since_prior_order": "days_lag_3"}).drop(columns=["order_id"])
lag_days_3
# Out:
#              days_lag_3   user_id
# order_lag_3
# -1                  NaN       NaN
#  45                 0.0   37913.0
#  75                 NaN  106387.0
#  84                 5.0   21551.0
#  87                 4.0  155476.0
# ...                 ...       ...
#  3421002           28.0   75028.0
#  3421024            NaN    9166.0
#  3421052            6.0  129045.0
#  3421072           26.0   50050.0
#  3421083           21.0   25247.0
#
# [182224 rows x 2 columns]

# %%
df_3 = df_2.copy()
df_3.head()
# Out:
#    reordered_ratio  order_dow  order_hour_of_day  order_frequency_in_days  \
# 0         0.705833   2.500000          10.300000                19.555556
# 1         0.447961   2.142857          10.571429                15.230769
# 2         0.658817   1.083333          16.416667                12.090909
# 3         0.028571   4.800000          12.600000                13.750000
# 4         0.377778   1.750000          16.000000                13.333333
#
#    item_count  no_orders  user_id
# 0    5.900000       10.0        1
# 1   13.928571       14.0        2
# 2    7.333333       12.0        3
# 3    3.600000        5.0        4
# 4    9.250000        4.0        5

# %%
# merge all days_lag_n with df_3
df_3 = pd.merge(df_3, lag_days_0, how="left", on="user_id")
df_3 = pd.merge(df_3, lag_days_1, how="left", on="user_id")
df_3 = pd.merge(df_3, lag_days_2, how="left", on="user_id")
df_3 = pd.merge(df_3, lag_days_3, how="left", on="user_id")
df_3
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  \
# 0              0.705833   2.500000          10.300000
# 1              0.447961   2.142857          10.571429
# 2              0.658817   1.083333          16.416667
# 3              0.028571   4.800000          12.600000
# 4              0.377778   1.750000          16.000000
# ...                 ...        ...                ...
# 206204         0.369048   3.666667          14.333333
# 206205         0.570676   2.477612          16.731343
# 206206         0.637144   2.562500          12.500000
# 206207         0.700368   2.653061          14.265306
# 206208         0.536752   2.769231          13.615385
#
#         order_frequency_in_days  item_count  no_orders  user_id  days_lag_0  \
# 0                     19.555556    5.900000       10.0        1        30.0
# 1                     15.230769   13.928571       14.0        2        13.0
# 2                     12.090909    7.333333       12.0        3        15.0
# 3                     13.750000    3.600000        5.0        4         0.0
# 4                     13.333333    9.250000        4.0        5        19.0
# ...                         ...         ...        ...      ...         ...
# 206204                20.000000   10.666667        3.0   206205        10.0
# 206205                 3.772727    4.253731       67.0   206206        11.0
# 206206                14.333333   13.937500       16.0   206207        18.0
# 206207                 7.437500   13.816327       49.0   206208         7.0
# 206208                17.500000    9.923077       13.0   206209         7.0
#
#         days_lag_1  days_lag_2  days_lag_3
# 0              0.0        14.0        20.0
# 1             30.0        28.0        30.0
# 2             11.0        17.0         7.0
# 3             15.0        21.0        19.0
# 4             10.0        11.0         NaN
# ...            ...         ...         ...
# 206204        30.0         NaN         NaN
# 206205        14.0        10.0         2.0
# 206206         7.0         4.0        30.0
# 206207         5.0         9.0        13.0
# 206208        18.0        30.0        29.0
#
# [206209 rows x 11 columns]

# %%
# calculate mean frequency without days_lag_0
# formula = (mean * n - x0)/(n-1)
# mind that no_orders = n+1
df_3["order_frequency_without_lag_0"] = (df_3["order_frequency_in_days"] * (df_3["no_orders"]-1)-df_3["days_lag_0"])/(df_3["no_orders"]-2)
df_3
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  \
# 0              0.705833   2.500000          10.300000
# 1              0.447961   2.142857          10.571429
# 2              0.658817   1.083333          16.416667
# 3              0.028571   4.800000          12.600000
# 4              0.377778   1.750000          16.000000
# ...                 ...        ...                ...
# 206204         0.369048   3.666667          14.333333
# 206205         0.570676   2.477612          16.731343
# 206206         0.637144   2.562500          12.500000
# 206207         0.700368   2.653061          14.265306
# 206208         0.536752   2.769231          13.615385
#
#         order_frequency_in_days  item_count  no_orders  user_id  days_lag_0  \
# 0                     19.555556    5.900000       10.0        1        30.0
# 1                     15.230769   13.928571       14.0        2        13.0
# 2                     12.090909    7.333333       12.0        3        15.0
# 3                     13.750000    3.600000        5.0        4         0.0
# 4                     13.333333    9.250000        4.0        5        19.0
# ...                         ...         ...        ...      ...         ...
# 206204                20.000000   10.666667        3.0   206205        10.0
# 206205                 3.772727    4.253731       67.0   206206        11.0
# 206206                14.333333   13.937500       16.0   206207        18.0
# 206207                 7.437500   13.816327       49.0   206208         7.0
# 206208                17.500000    9.923077       13.0   206209         7.0
#
#         days_lag_1  days_lag_2  days_lag_3  order_frequency_without_lag_0
# 0              0.0        14.0        20.0                      18.250000
# 1             30.0        28.0        30.0                      15.416667
# 2             11.0        17.0         7.0                      11.800000
# 3             15.0        21.0        19.0                      18.333333
# 4             10.0        11.0         NaN                      10.500000
# ...            ...         ...         ...                            ...
# 206204        30.0         NaN         NaN                      30.000000
# 206205        14.0        10.0         2.0                       3.661538
# 206206         7.0         4.0        30.0                      14.071429
# 206207         5.0         9.0        13.0                       7.446809
# 206208        18.0        30.0        29.0                      18.454545
#
# [206209 rows x 12 columns]

# %%
# impute days_lag_2 and days_lag_3 with mean
df_4 = df_3.copy()
df_4.days_lag_3[df_4.days_lag_3.isna()] = df_4.order_frequency_without_lag_0[df_4.days_lag_3.isna()]
df_4.days_lag_2[df_4.days_lag_2.isna()] = df_4.order_frequency_without_lag_0[df_4.days_lag_2.isna()]
df_4
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  \
# 0              0.705833   2.500000          10.300000
# 1              0.447961   2.142857          10.571429
# 2              0.658817   1.083333          16.416667
# 3              0.028571   4.800000          12.600000
# 4              0.377778   1.750000          16.000000
# ...                 ...        ...                ...
# 206204         0.369048   3.666667          14.333333
# 206205         0.570676   2.477612          16.731343
# 206206         0.637144   2.562500          12.500000
# 206207         0.700368   2.653061          14.265306
# 206208         0.536752   2.769231          13.615385
#
#         order_frequency_in_days  item_count  no_orders  user_id  days_lag_0  \
# 0                     19.555556    5.900000       10.0        1        30.0
# 1                     15.230769   13.928571       14.0        2        13.0
# 2                     12.090909    7.333333       12.0        3        15.0
# 3                     13.750000    3.600000        5.0        4         0.0
# 4                     13.333333    9.250000        4.0        5        19.0
# ...                         ...         ...        ...      ...         ...
# 206204                20.000000   10.666667        3.0   206205        10.0
# 206205                 3.772727    4.253731       67.0   206206        11.0
# 206206                14.333333   13.937500       16.0   206207        18.0
# 206207                 7.437500   13.816327       49.0   206208         7.0
# 206208                17.500000    9.923077       13.0   206209         7.0
#
#         days_lag_1  days_lag_2  days_lag_3  order_frequency_without_lag_0
# 0              0.0        14.0        20.0                      18.250000
# 1             30.0        28.0        30.0                      15.416667
# 2             11.0        17.0         7.0                      11.800000
# 3             15.0        21.0        19.0                      18.333333
# 4             10.0        11.0        10.5                      10.500000
# ...            ...         ...         ...                            ...
# 206204        30.0        30.0        30.0                      30.000000
# 206205        14.0        10.0         2.0                       3.661538
# 206206         7.0         4.0        30.0                      14.071429
# 206207         5.0         9.0        13.0                       7.446809
# 206208        18.0        30.0        29.0                      18.454545
#
# [206209 rows x 12 columns]

# %%
# create binary feature: will the customer come back within 14 days? --> days_lag_0

df_4["comes_within_14_days"] = 0
df_4["comes_within_14_days"][df_4["days_lag_0"]<14] = 1 
df_4
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  \
# 0              0.705833   2.500000          10.300000
# 1              0.447961   2.142857          10.571429
# 2              0.658817   1.083333          16.416667
# 3              0.028571   4.800000          12.600000
# 4              0.377778   1.750000          16.000000
# ...                 ...        ...                ...
# 206204         0.369048   3.666667          14.333333
# 206205         0.570676   2.477612          16.731343
# 206206         0.637144   2.562500          12.500000
# 206207         0.700368   2.653061          14.265306
# 206208         0.536752   2.769231          13.615385
#
#         order_frequency_in_days  item_count  no_orders  user_id  days_lag_0  \
# 0                     19.555556    5.900000       10.0        1        30.0
# 1                     15.230769   13.928571       14.0        2        13.0
# 2                     12.090909    7.333333       12.0        3        15.0
# 3                     13.750000    3.600000        5.0        4         0.0
# 4                     13.333333    9.250000        4.0        5        19.0
# ...                         ...         ...        ...      ...         ...
# 206204                20.000000   10.666667        3.0   206205        10.0
# 206205                 3.772727    4.253731       67.0   206206        11.0
# 206206                14.333333   13.937500       16.0   206207        18.0
# 206207                 7.437500   13.816327       49.0   206208         7.0
# 206208                17.500000    9.923077       13.0   206209         7.0
#
#         days_lag_1  days_lag_2  days_lag_3  order_frequency_without_lag_0  \
# 0              0.0        14.0        20.0                      18.250000
# 1             30.0        28.0        30.0                      15.416667
# 2             11.0        17.0         7.0                      11.800000
# 3             15.0        21.0        19.0                      18.333333
# 4             10.0        11.0        10.5                      10.500000
# ...            ...         ...         ...                            ...
# 206204        30.0        30.0        30.0                      30.000000
# 206205        14.0        10.0         2.0                       3.661538
# 206206         7.0         4.0        30.0                      14.071429
# 206207         5.0         9.0        13.0                       7.446809
# 206208        18.0        30.0        29.0                      18.454545
#
#         comes_within_14_days
# 0                          0
# 1                          1
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 206204                     1
# 206205                     1
# 206206                     0
# 206207                     1
# 206208                     1
#
# [206209 rows x 13 columns]

# %% [markdown]
# ## Train-Test Split

# %%
print(f"There are {len(pd.unique(df.user_id))} unique customers in the data set.")
# Out:
# There are 206209 unique customers in the data set.

# %%
# create train test split on customers
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df_4, test_size=0.25)

# %%
# check size
len(df_test), len(df_train) , len(df_test)+len(df_train) , len(df_4)
# Out:
# (51553, 154656, 206209, 206209)

# %% [markdown]
# ## Model Training

# %%
df_train
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  \
# 71793          0.222222   5.333333          11.666667
# 203613         0.486189   3.923077          14.615385
# 196903         0.418448   3.052632          13.842105
# 12711          0.741667   4.400000          12.700000
# 178049         0.381985   3.545455          13.818182
# ...                 ...        ...                ...
# 167350         0.653161   2.928571          13.238095
# 190078         0.055556   2.000000          16.000000
# 125058         0.354066   3.818182          12.454545
# 61306          0.347449   2.285714          11.000000
# 27859          0.513668   3.400000          14.320000
#
#         order_frequency_in_days  item_count  no_orders  user_id  days_lag_0  \
# 71793                  0.500000    2.666667        3.0    71794         1.0
# 203613                15.500000   10.384615       13.0   203614        12.0
# 196903                 6.833333    8.631579       19.0   196904         6.0
# 12711                 23.777778    2.800000       10.0    12712        30.0
# 178049                20.100000   13.000000       11.0   178050        30.0
# ...                         ...         ...        ...      ...         ...
# 167350                 7.878049    6.523810       42.0   167351        30.0
# 190078                15.000000   18.333333        3.0   190079        15.0
# 125058                12.800000   21.272727       11.0   125059        17.0
# 61306                 18.666667    7.285714        7.0    61307         8.0
# 27859                  7.500000   12.200000       25.0    27860        18.0
#
#         days_lag_1  days_lag_2  days_lag_3  order_frequency_without_lag_0  \
# 71793          0.0         0.0         0.0                       0.000000
# 203613        30.0        13.0        30.0                      15.818182
# 196903         3.0        16.0         5.0                       6.882353
# 12711         12.0        30.0        30.0                      23.000000
# 178049        30.0        12.0         6.0                      19.000000
# ...            ...         ...         ...                            ...
# 167350         4.0         9.0         6.0                       7.325000
# 190078        15.0        15.0        15.0                      15.000000
# 125058        13.0         6.0         7.0                      12.333333
# 61306          4.0        10.0        30.0                      20.800000
# 27859         11.0         5.0         9.0                       7.043478
#
#         comes_within_14_days
# 71793                      1
# 203613                     1
# 196903                     1
# 12711                      0
# 178049                     0
# ...                      ...
# 167350                     0
# 190078                     0
# 125058                     0
# 61306                      1
# 27859                      0
#
# [154656 rows x 13 columns]

# %%
# try simple logistic regression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0)
X = df_train[["reordered_ratio", "order_dow","order_hour_of_day", "item_count", "no_orders", "order_frequency_without_lag_0", "days_lag_1", "days_lag_2", "days_lag_3", ]]
y = df_train["comes_within_14_days"]
clf.fit(X, y)
# Out:
# LogisticRegression(random_state=0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(clf.predict(X), y)
# Out:
# 0.6933129008897165

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y, clf.predict(X))
fpr, tpr, thresholds
metrics.auc(fpr, tpr)
# Out:
# 0.6926815374513986

# %%
metrics.plot_roc_curve(clf, X, y)  
plt.show()

# %% [markdown]
# ## Apply on test set

# %%
# logistic regression

X_test = df_test[["reordered_ratio", "order_dow","order_hour_of_day", "item_count", "no_orders", "order_frequency_without_lag_0", "days_lag_1", "days_lag_2", "days_lag_3", ]]
y_test = df_test["comes_within_14_days"]

fpr, tpr, thresholds = metrics.roc_curve(y_test, clf.predict(X_test))
fpr, tpr, thresholds
metrics.auc(fpr, tpr)
# Out:
# 0.6888556428743118

# %%
metrics.plot_roc_curve(clf, X_test, y_test)  
plt.show()

# %% [markdown]
# ## Try Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# clf_rf = RandomForestClassifier(max_depth=4, random_state=0)
# clf_rf.fit(X, y)

# %%
from sklearn.model_selection import RandomizedSearchCV
from random import randint

param = {"max_depth": [1,3,4,5, 8, 10, None], 
         "n_estimators":[50, 70, 100, 150], 
          "max_features": [2,3,4,5,6],
          "criterion" : ['gini', 'entropy'],
          "bootstrap":[True, False],
          "min_samples_split": [1,2,3,4]}

rnd_search = RandomizedSearchCV(RandomForestClassifier(), param, n_iter = 30, cv=5, scoring ="roc_auc", n_jobs=-1,verbose=10)

rnd_search.fit(X,y)
rnd_search.best_params_
rnd_search.best_score_

# rf = RandomForestClassifier(max_depth=4, random_state=0)
# clf_rf = RandomizedSearchCV(rf, distributions, random_state=0)
# search = clf_rf.fit(X,y)
# search.best_params_
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 19.6min finished
# 0.7619706954142621

# %%
rnd_search.best_params_
# Out:
# {'n_estimators': 70,
#  'min_samples_split': 3,
#  'max_features': 3,
#  'max_depth': 10,
#  'criterion': 'gini',
#  'bootstrap': True}

# %%
metrics.plot_roc_curve(rnd_search, X_test, y_test)  
plt.show()

# %% [markdown]
# ## Time shift for predictions

# %%
X.head()
# Out:
#         reordered_ratio  order_dow  order_hour_of_day  item_count  no_orders  \
# 71793          0.222222   5.333333          11.666667    2.666667        3.0
# 203613         0.486189   3.923077          14.615385   10.384615       13.0
# 196903         0.418448   3.052632          13.842105    8.631579       19.0
# 12711          0.741667   4.400000          12.700000    2.800000       10.0
# 178049         0.381985   3.545455          13.818182   13.000000       11.0
#
#         order_frequency_without_lag_0  days_lag_1  days_lag_2  days_lag_3
# 71793                        0.000000         0.0         0.0         0.0
# 203613                      15.818182        30.0        13.0        30.0
# 196903                       6.882353         3.0        16.0         5.0
# 12711                       23.000000        12.0        30.0        30.0
# 178049                      19.000000        30.0        12.0         6.0

# %%
X_shifted = df_4[["reordered_ratio", "order_dow","order_hour_of_day", "item_count", "no_orders", "order_frequency_in_days", "days_lag_0", "days_lag_1", "days_lag_2"]]
X_shifted.head()
# Out:
#    reordered_ratio  order_dow  order_hour_of_day  item_count  no_orders  \
# 0         0.705833   2.500000          10.300000    5.900000       10.0
# 1         0.447961   2.142857          10.571429   13.928571       14.0
# 2         0.658817   1.083333          16.416667    7.333333       12.0
# 3         0.028571   4.800000          12.600000    3.600000        5.0
# 4         0.377778   1.750000          16.000000    9.250000        4.0
#
#    order_frequency_in_days  days_lag_0  days_lag_1  days_lag_2
# 0                19.555556        30.0         0.0        14.0
# 1                15.230769        13.0        30.0        28.0
# 2                12.090909        15.0        11.0        17.0
# 3                13.750000         0.0        15.0        21.0
# 4                13.333333        19.0        10.0        11.0

# %%
df_5 = df_4.copy()
df_5["prediction"] = pd.DataFrame( rnd_search.predict_proba(X_shifted)[:,1])
df_5[df_5["prediction"]>0.8].head(30)
# Out:
#      reordered_ratio  order_dow  order_hour_of_day  order_frequency_in_days  \
# 12          0.627017   3.083333          14.916667                 7.636364
# 26          0.669270   2.814815          12.469136                 4.437500
# 30          0.281645   2.200000          11.700000                 4.894737
# 49          0.823572   2.791045          11.253731                 5.409091
# 53          0.661967   3.428571          12.844156                 4.776316
# 89          0.885351   3.535211          12.126761                 3.471429
# 111         0.639927   3.115385          14.153846                 8.000000
# 131         0.658234   2.458333          11.458333                 3.347826
# 132         0.472496   2.650000          11.050000                 6.473684
# 139         0.731193   3.118421          13.986842                 4.840000
# 141         0.781322   2.844444          14.022222                 7.272727
# 144         0.477083   3.000000          13.250000                 3.714286
# 151         0.789800   2.800000          14.292308                 5.593750
# 153         0.682006   1.142857          14.228571                 9.647059
# 176         0.559524   2.428571          13.357143                 6.384615
# 186         0.671469   2.437500          13.437500                 7.000000
# 194         0.780172   3.103448          11.793103                 5.473684
# 196         0.615434   3.450000          14.250000                 3.684211
# 203         0.650404   2.810345          14.465517                 6.105263
# 209         0.820982   2.808081          14.151515                 3.316327
# 218         0.683429   2.878788          14.090909                10.156250
# 221         0.668445   2.928571           9.485714                 5.246377
# 222         0.757917   1.142857           8.897959                 7.437500
# 226         0.646693   2.612903          15.161290                 8.866667
# 235         0.398327   2.800000          13.355556                 6.000000
# 247         0.786058   2.431034          14.086207                 5.929825
# 253         0.495897   4.090909          14.454545                 4.400000
# 256         0.486303   3.150000          15.100000                 4.368421
# 261         0.480311   3.244444          13.400000                 7.386364
# 277         0.875032   2.647059          13.044118                 2.850746
#
#      item_count  no_orders  user_id  days_lag_0  days_lag_1  days_lag_2  \
# 12     6.750000       12.0       13         6.0         8.0         7.0
# 26     9.481481       81.0       27         6.0         6.0         5.0
# 30    14.950000       20.0       31         0.0         4.0         0.0
# 49     6.761194       67.0       50         6.0         3.0         6.0
# 53     8.038961       77.0       54         1.0         8.0         2.0
# 89     9.436620       71.0       90         1.0         4.0         4.0
# 111    6.076923       26.0      112         5.0         5.0         2.0
# 131    4.833333       24.0      132         5.0         1.0         2.0
# 132   27.200000       20.0      133         6.0         7.0         5.0
# 139   15.144737       76.0      140         4.0         2.0         6.0
# 141    8.177778       45.0      142         4.0         4.0         2.0
# 144    8.375000        8.0      145         3.0         6.0        11.0
# 151   10.707692       65.0      152         1.0         3.0         3.0
# 153   17.714286       35.0      154         4.0         7.0         8.0
# 176    3.428571       14.0      177         0.0         5.0         7.0
# 186    6.343750       32.0      187         8.0        15.0         1.0
# 194    3.189655       58.0      195         1.0         3.0         7.0
# 196   22.400000       20.0      197         1.0         3.0         4.0
# 203    8.879310       58.0      204         8.0        10.0        17.0
# 209   14.909091       99.0      210         3.0         4.0         4.0
# 218   12.242424       33.0      219         2.0         4.0         4.0
# 221    6.914286       70.0      222         1.0         6.0         1.0
# 222   13.122449       49.0      223         7.0         7.0         7.0
# 226   18.129032       31.0      227         7.0         3.0         3.0
# 235   11.444444       45.0      236         2.0         6.0        10.0
# 247    6.758621       58.0      248         2.0         4.0         0.0
# 253    9.545455       11.0      254         3.0         8.0         0.0
# 256    6.050000       20.0      257        10.0         3.0         2.0
# 261    5.822222       45.0      262         1.0         2.0         1.0
# 277    3.926471       68.0      278         3.0         4.0        10.0
#
#      days_lag_3  order_frequency_without_lag_0  comes_within_14_days  \
# 12          7.0                       7.800000                     1
# 26          4.0                       4.417722                     1
# 30          8.0                       5.166667                     1
# 49         10.0                       5.400000                     1
# 53          2.0                       4.826667                     1
# 89          4.0                       3.507246                     1
# 111         4.0                       8.125000                     1
# 131         3.0                       3.272727                     1
# 132         8.0                       6.500000                     1
# 139         1.0                       4.851351                     1
# 141         5.0                       7.348837                     1
# 144         1.0                       3.833333                     1
# 151         8.0                       5.666667                     1
# 153        13.0                       9.818182                     1
# 176         9.0                       6.916667                     1
# 186         3.0                       6.966667                     1
# 194        10.0                       5.553571                     1
# 196         3.0                       3.833333                     1
# 203         4.0                       6.071429                     1
# 209         2.0                       3.319588                     1
# 218         4.0                      10.419355                     1
# 221        10.0                       5.308824                     1
# 222         7.0                       7.446809                     1
# 226         3.0                       8.931034                     1
# 235        18.0                       6.093023                     1
# 247         9.0                       6.000000                     1
# 253         6.0                       4.555556                     1
# 256        11.0                       4.055556                     1
# 261         0.0                       7.534884                     1
# 277         3.0                       2.848485                     1
#
#      prediction
# 12     0.824974
# 26     0.954779
# 30     0.828252
# 49     0.955958
# 53     0.953489
# 89     0.969663
# 111    0.803677
# 131    0.920556
# 132    0.822546
# 139    0.968204
# 141    0.906983
# 144    0.813692
# 151    0.962042
# 153    0.814041
# 176    0.841378
# 186    0.801253
# 194    0.943816
# 196    0.904041
# 203    0.894494
# 209    0.990189
# 218    0.820551
# 221    0.958006
# 222    0.928095
# 226    0.806401
# 235    0.814623
# 247    0.930052
# 253    0.848645
# 256    0.847966
# 261    0.867290
# 277    0.946997

# %%
df_5[df_5["prediction"]<0.4].head(30)
# Out:
#     reordered_ratio  order_dow  order_hour_of_day  order_frequency_in_days  \
# 0          0.705833   2.500000          10.300000                19.555556
# 1          0.447961   2.142857          10.571429                15.230769
# 7          0.305983   4.000000           2.666667                30.000000
# 8          0.254545   2.000000          14.333333                18.000000
# 9          0.325665   3.600000          16.600000                19.750000
# 10         0.345037   4.285714          10.857143                20.500000
# 11         0.145455   3.000000           9.400000                25.000000
# 15         0.375842   2.000000          13.833333                21.800000
# 22         0.083333   3.250000          11.750000                14.666667
# 24         0.138889   2.333333          17.666667                30.000000
# 29         0.562500   1.250000          12.750000                21.571429
# 31         0.307182   2.400000          13.200000                20.250000
# 32         0.438914   2.000000          16.333333                28.500000
# 33         0.225000   2.400000          12.400000                20.000000
# 34         0.513041   4.000000          15.888889                21.375000
# 37         0.549145   3.333333          11.000000                21.000000
# 38         0.526373   3.428571          14.428571                12.000000
# 40         0.265370   1.800000          16.000000                25.750000
# 41         0.589286   2.062500          13.750000                13.866667
# 43         0.162393   0.333333           8.333333                30.000000
# 44         0.035714   3.000000          16.750000                20.000000
# 45         0.640884   0.789474          14.105263                17.722222
# 47         0.444923   5.500000          13.100000                21.666667
# 48         0.050000   2.750000          13.375000                28.142857
# 50         0.128205   3.333333          14.000000                15.000000
# 52         0.023810   3.000000          17.000000                16.500000
# 54         0.507143   1.428571          13.142857                17.666667
# 58         0.395298   2.200000          11.700000                16.777778
# 59         0.392411   2.750000          14.500000                24.857143
# 60         0.118330   3.250000          11.250000                24.666667
#
#     item_count  no_orders  user_id  days_lag_0  days_lag_1  days_lag_2  \
# 0     5.900000       10.0        1        30.0         0.0        14.0
# 1    13.928571       14.0        2        13.0        30.0        28.0
# 7    16.333333        3.0        8        30.0        30.0        30.0
# 8    25.333333        3.0        9        30.0         6.0         6.0
# 9    28.600000        5.0       10        23.0        14.0        12.0
# 10   13.428571        7.0       11        30.0         7.0        30.0
# 11   14.800000        5.0       12        30.0        26.0        14.0
# 15   11.666667        6.0       16        26.0        30.0        12.0
# 22   10.000000        4.0       23        30.0         5.0         9.0
# 24    7.000000        3.0       25        30.0        30.0        30.0
# 29    1.375000        8.0       30        30.0        28.0        27.0
# 31   22.800000        5.0       32        30.0         1.0        20.0
# 32   17.666667        3.0       33        30.0        27.0        27.0
# 33    6.400000        5.0       34        21.0        10.0        21.0
# 34   20.444444        9.0       35        28.0        30.0         4.0
# 37   16.250000       12.0       38        30.0         9.0        27.0
# 38   20.142857        7.0       39        30.0        15.0         7.0
# 40   13.000000        5.0       41        27.0        22.0        30.0
# 41    8.312500       16.0       42        14.0        30.0        22.0
# 43   12.333333        3.0       44        30.0        30.0        30.0
# 44    4.500000        4.0       45        30.0        18.0        12.0
# 45    8.263158       19.0       46        21.0        22.0        30.0
# 47   11.300000       10.0       48        14.0        13.0        14.0
# 48    5.875000        8.0       49        28.0        30.0        30.0
# 50    9.666667        3.0       51        17.0        13.0        13.0
# 52   11.666667        3.0       53        16.0        17.0        17.0
# 54   12.428571        7.0       55        13.0        28.0        15.0
# 58    9.200000       10.0       59        11.0        30.0        29.0
# 59    8.375000        8.0       60        30.0        30.0        25.0
# 60   21.750000        4.0       61        30.0        14.0        30.0
#
#     days_lag_3  order_frequency_without_lag_0  comes_within_14_days  \
# 0         20.0                      18.250000                     0
# 1         30.0                      15.416667                     1
# 7         30.0                      30.000000                     0
# 8          6.0                       6.000000                     0
# 9         30.0                      18.666667                     0
# 10        30.0                      18.600000                     0
# 11        30.0                      23.333333                     0
# 15        21.0                      20.750000                     0
# 22         7.0                       7.000000                     0
# 24        30.0                      30.000000                     0
# 29        30.0                      20.166667                     0
# 31        30.0                      17.000000                     0
# 32        27.0                      27.000000                     0
# 33        28.0                      19.666667                     0
# 34         1.0                      20.428571                     0
# 37         7.0                      20.100000                     0
# 38         7.0                       8.400000                     0
# 40        24.0                      25.333333                     0
# 41         9.0                      13.857143                     0
# 43        30.0                      30.000000                     0
# 44        15.0                      15.000000                     0
# 45        21.0                      17.529412                     0
# 47        29.0                      22.625000                     0
# 48        19.0                      28.166667                     0
# 50        13.0                      13.000000                     0
# 52        17.0                      17.000000                     0
# 54        13.0                      18.600000                     1
# 58        14.0                      17.500000                     1
# 59        24.0                      24.000000                     0
# 60        22.0                      22.000000                     0
#
#     prediction
# 0     0.366573
# 1     0.384183
# 7     0.245317
# 8     0.339340
# 9     0.253950
# 10    0.342897
# 11    0.219586
# 15    0.244266
# 22    0.377391
# 24    0.223973
# 29    0.194244
# 31    0.283378
# 32    0.189004
# 33    0.312090
# 34    0.266762
# 37    0.329475
# 38    0.382266
# 40    0.232436
# 41    0.365629
# 43    0.205160
# 44    0.265567
# 45    0.348153
# 47    0.290273
# 48    0.284597
# 50    0.349838
# 52    0.325506
# 54    0.317100
# 58    0.394377
# 59    0.256161
# 60    0.204770

# %%
y_pred_final = pd.DataFrame(df_4["user_id"])
y_pred_final["prediction"] = rnd_search.predict_proba(X_shifted)[:,1]
y_pred_final
# Out:
#         user_id  prediction
# 0             1    0.366573
# 1             2    0.384183
# 2             3    0.416431
# 3             4    0.458975
# 4             5    0.411377
# ...         ...         ...
# 206204   206205    0.343324
# 206205   206206    0.838659
# 206206   206207    0.520553
# 206207   206208    0.909173
# 206208   206209    0.414728
#
# [206209 rows x 2 columns]

# %%
pred_idx["yhat"] = y_pred_final["prediction"]
pred_idx
# Out:
#         user_id  order_number      yhat
# 0             1            11  0.366573
# 1             2            15  0.384183
# 2             3            13  0.416431
# 3             4             6  0.458975
# 4             5             5  0.411377
# ...         ...           ...       ...
# 206204   206205             4  0.343324
# 206205   206206            68  0.838659
# 206206   206207            17  0.520553
# 206207   206208            50  0.909173
# 206208   206209            14  0.414728
#
# [206209 rows x 3 columns]

# %%
pred_idx.to_parquet("e02-06.parquet")

# %% [markdown]
# ## Appendix: Check impact of features by simple linear regression

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
# X = df_train[["reordered_ratio", "order_dow","order_hour_of_day", "item_count", "no_orders", "order_frequency_without_lag_0", "days_lag_1", "days_lag_2", "days_lag_3", ]]
# y = df_train["comes_within_14_days"]
lm.fit(X, y)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 0.02585943,  0.00948823, -0.002138  ,  0.00101159,  0.00512139,
#        -0.00593547, -0.00675568, -0.00443691, -0.00305349])

# %%
import statsmodels.api as sm
from scipy import stats

# X2 = sm.add_constant(X)
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     comes_within_14_days   R-squared (uncentered):                   0.572
# Model:                              OLS   Adj. R-squared (uncentered):              0.572
# Method:                   Least Squares   F-statistic:                          2.293e+04
# Date:                  Sun, 29 Nov 2020   Prob (F-statistic):                        0.00
# Time:                          14:25:49   Log-Likelihood:                         -98229.
# No. Observations:                154656   AIC:                                  1.965e+05
# Df Residuals:                    154647   BIC:                                  1.966e+05
# Df Model:                             9
# Covariance Type:              nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# reordered_ratio                   0.1731      0.007     26.410      0.000       0.160       0.186
# order_dow                         0.0436      0.001     38.224      0.000       0.041       0.046
# order_hour_of_day                 0.0285      0.000     81.660      0.000       0.028       0.029
# item_count                        0.0037      0.000     18.771      0.000       0.003       0.004
# no_orders                         0.0058   9.49e-05     61.238      0.000       0.006       0.006
# order_frequency_without_lag_0    -0.0013      0.000     -3.546      0.000      -0.002      -0.001
# days_lag_1                       -0.0067      0.000    -40.994      0.000      -0.007      -0.006
# days_lag_2                       -0.0044      0.000    -26.447      0.000      -0.005      -0.004
# days_lag_3                       -0.0030      0.000    -17.237      0.000      -0.003      -0.003
# ==============================================================================
# Omnibus:                   516321.864   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11328.001
# Skew:                           0.144   Prob(JB):                         0.00
# Kurtosis:                       1.706   Cond. No.                         226.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
